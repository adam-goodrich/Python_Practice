# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Homework: Plotting With Pandas
#
# _Authors: Kevin Coyle (L.A.)_
#
# ---

# %% [markdown]
# Welcome!

# %% [markdown]
# #### Pandas: Plotting Practice Problems
#
# In this homework, you're going to write code for a few problems.
#
# You'll practice the following programming concepts we've covered in class:
# * Plotting with Pandas.
# * Determining best plot given a data set.

# %% [markdown]
# #### #1. Import Pandas, `Matplotlib.pyplot`, and NumPy. Don't forget the line that makes `matplotlib` render in a Jupyter Notebook!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
nba_df = pd.read_csv('NBA_players_2015.csv')

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
nba_df.head()
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #4. Create a histogram of the `age` column.

# %%
nba_df["age"].plot(kind="hist")

# %% [markdown]
# #### #5. Create a histogram of the `age` column, but change the number of bins to `20`.

# %%
nba_df["age"].plot(kind="hist", bins=20)

# %% [markdown]
# #### #6. Discuss the difference in the two plots and the implications.

# %% [markdown]
# While skewed, the plot with fewer bins leads one to believe that the bin to the right of the highest-numbered age bin is the second largest. The second-largest bin occurs right after 22 and before 25.

# %% [markdown]
# #### #7. Rename the `position` column `'pos'` with the following `C:5`, `G:1`, and `F:3`. Then create a scatter matrix plot with the `'pos'`, `'pts'`, `'age'`, and `'fg'` columns.

# %%
nba_df
# Out:
#      season_end          player pos  age bref_team_id   g  gs    mp   fg  \
# 0          2015      Quincy Acy   F   24          NYK  52  21  19.2  2.2
# 1          2015    Jordan Adams   G   20          MEM  18   0   7.3  1.0
# 2          2015    Steven Adams   C   21          OKC  51  50  24.2  3.0
# 3          2015     Jeff Adrien   F   28          MIN  17   0  12.6  1.1
# 4          2015   Arron Afflalo   G   29          TOT  60  54  32.5  5.0
# ..          ...             ...  ..  ...          ...  ..  ..   ...  ...
# 473        2015     James Young   G   19          BOS  27   0  10.9  1.1
# 474        2015      Nick Young   G   29          LAL  42   0  23.8  4.1
# 475        2015  Thaddeus Young   F   26          TOT  58  50  31.8  5.9
# 476        2015     Cody Zeller   C   22          CHO  61  44  24.1  2.8
# 477        2015    Tyler Zeller   C   25          BOS  62  39  20.8  3.9
#
#       fga  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0     4.6  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1     2.1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2     5.5  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3     2.6  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4    11.8  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
# ..    ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 473   3.3  ...   3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2 -4.1  -0.2
# 474  11.3  ...   7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2 -3.2  -0.3
# 475  12.8  ...   9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1  0.3   1.1
# 476   6.1  ...  12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5  0.7   1.0
# 477   7.1  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
#
# [478 rows x 49 columns]

# %%
nba_df = nba_df.replace(to_replace="C", value=5)
nba_df
# Out:
#      season_end          player pos  age bref_team_id   g  gs    mp   fg  \
# 0          2015      Quincy Acy   F   24          NYK  52  21  19.2  2.2
# 1          2015    Jordan Adams   G   20          MEM  18   0   7.3  1.0
# 2          2015    Steven Adams   5   21          OKC  51  50  24.2  3.0
# 3          2015     Jeff Adrien   F   28          MIN  17   0  12.6  1.1
# 4          2015   Arron Afflalo   G   29          TOT  60  54  32.5  5.0
# ..          ...             ...  ..  ...          ...  ..  ..   ...  ...
# 473        2015     James Young   G   19          BOS  27   0  10.9  1.1
# 474        2015      Nick Young   G   29          LAL  42   0  23.8  4.1
# 475        2015  Thaddeus Young   F   26          TOT  58  50  31.8  5.9
# 476        2015     Cody Zeller   5   22          CHO  61  44  24.1  2.8
# 477        2015    Tyler Zeller   5   25          BOS  62  39  20.8  3.9
#
#       fga  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0     4.6  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1     2.1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2     5.5  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3     2.6  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4    11.8  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
# ..    ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 473   3.3  ...   3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2 -4.1  -0.2
# 474  11.3  ...   7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2 -3.2  -0.3
# 475  12.8  ...   9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1  0.3   1.1
# 476   6.1  ...  12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5  0.7   1.0
# 477   7.1  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
#
# [478 rows x 49 columns]

# %%
nba_df = nba_df.replace(to_replace="G", value=1)
nba_df
# Out:
#      season_end          player pos  age bref_team_id   g  gs    mp   fg  \
# 0          2015      Quincy Acy   F   24          NYK  52  21  19.2  2.2
# 1          2015    Jordan Adams   1   20          MEM  18   0   7.3  1.0
# 2          2015    Steven Adams   5   21          OKC  51  50  24.2  3.0
# 3          2015     Jeff Adrien   F   28          MIN  17   0  12.6  1.1
# 4          2015   Arron Afflalo   1   29          TOT  60  54  32.5  5.0
# ..          ...             ...  ..  ...          ...  ..  ..   ...  ...
# 473        2015     James Young   1   19          BOS  27   0  10.9  1.1
# 474        2015      Nick Young   1   29          LAL  42   0  23.8  4.1
# 475        2015  Thaddeus Young   F   26          TOT  58  50  31.8  5.9
# 476        2015     Cody Zeller   5   22          CHO  61  44  24.1  2.8
# 477        2015    Tyler Zeller   5   25          BOS  62  39  20.8  3.9
#
#       fga  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0     4.6  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1     2.1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2     5.5  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3     2.6  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4    11.8  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
# ..    ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 473   3.3  ...   3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2 -4.1  -0.2
# 474  11.3  ...   7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2 -3.2  -0.3
# 475  12.8  ...   9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1  0.3   1.1
# 476   6.1  ...  12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5  0.7   1.0
# 477   7.1  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
#
# [478 rows x 49 columns]

# %%
nba_df = nba_df.replace(to_replace="F", value=3)
nba_df
# Out:
#      season_end          player  pos  age bref_team_id   g  gs    mp   fg  \
# 0          2015      Quincy Acy    3   24          NYK  52  21  19.2  2.2
# 1          2015    Jordan Adams    1   20          MEM  18   0   7.3  1.0
# 2          2015    Steven Adams    5   21          OKC  51  50  24.2  3.0
# 3          2015     Jeff Adrien    3   28          MIN  17   0  12.6  1.1
# 4          2015   Arron Afflalo    1   29          TOT  60  54  32.5  5.0
# ..          ...             ...  ...  ...          ...  ..  ..   ...  ...
# 473        2015     James Young    1   19          BOS  27   0  10.9  1.1
# 474        2015      Nick Young    1   29          LAL  42   0  23.8  4.1
# 475        2015  Thaddeus Young    3   26          TOT  58  50  31.8  5.9
# 476        2015     Cody Zeller    5   22          CHO  61  44  24.1  2.8
# 477        2015    Tyler Zeller    5   25          BOS  62  39  20.8  3.9
#
#       fga  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0     4.6  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1     2.1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2     5.5  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3     2.6  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4    11.8  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
# ..    ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 473   3.3  ...   3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2 -4.1  -0.2
# 474  11.3  ...   7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2 -3.2  -0.3
# 475  12.8  ...   9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1  0.3   1.1
# 476   6.1  ...  12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5  0.7   1.0
# 477   7.1  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
#
# [478 rows x 49 columns]

# %%
nba_df
# Out:
#      season_end          player  pos  age bref_team_id   g  gs    mp   fg  \
# 0          2015      Quincy Acy    3   24          NYK  52  21  19.2  2.2
# 1          2015    Jordan Adams    1   20          MEM  18   0   7.3  1.0
# 2          2015    Steven Adams    5   21          OKC  51  50  24.2  3.0
# 3          2015     Jeff Adrien    3   28          MIN  17   0  12.6  1.1
# 4          2015   Arron Afflalo    1   29          TOT  60  54  32.5  5.0
# ..          ...             ...  ...  ...          ...  ..  ..   ...  ...
# 473        2015     James Young    1   19          BOS  27   0  10.9  1.1
# 474        2015      Nick Young    1   29          LAL  42   0  23.8  4.1
# 475        2015  Thaddeus Young    3   26          TOT  58  50  31.8  5.9
# 476        2015     Cody Zeller    5   22          CHO  61  44  24.1  2.8
# 477        2015    Tyler Zeller    5   25          BOS  62  39  20.8  3.9
#
#       fga  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0     4.6  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1     2.1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2     5.5  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3     2.6  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4    11.8  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
# ..    ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 473   3.3  ...   3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2 -4.1  -0.2
# 474  11.3  ...   7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2 -3.2  -0.3
# 475  12.8  ...   9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1  0.3   1.1
# 476   6.1  ...  12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5  0.7   1.0
# 477   7.1  ...  10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4  0.7   0.9
#
# [478 rows x 49 columns]

# %%
nba_df_scatter = nba_df

# %%
nba_df_scatter = pd.DataFrame(np.random.randn(1000, 4), columns=["pos", "pts", "age", "fg"])
pd.plotting.scatter_matrix(nba_df_scatter, alpha=0.2, figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x125ec1dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125fe6ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125f83e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125fa4b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10f81be90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f853b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f88dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f8c2b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10f8cc710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1236910d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1236faf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12372fc10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12376ff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1237a5c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12601ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126056c90>]],
#       dtype=object)

# %% [markdown]
# #### #8. Plot the number of guards, centers, and forwards in this data set.

# %%
nba_df["pos"].value_counts()
# Out:
# 1    200
# 3    199
# 5     79
# Name: pos, dtype: int64

# %%
nba_df["pos"].value_counts().plot(kind="bar")
plt.xticks(np.arange(3), ("Guards", "Forwards", "Centers"))
# Out:
# ([<matplotlib.axis.XTick at 0x1262c5910>,
#   <matplotlib.axis.XTick at 0x1262c1590>,
#   <matplotlib.axis.XTick at 0x12677e8d0>],
#  <a list of 3 Text xticklabel objects>)

# %% [markdown]
# The end!

# %% [markdown]
# #### Great job!
